# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

# %% [markdown]
# Load the model

# %%
model_name = "yiyanghkust/finbert-tone"
finbert = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %% [markdown]
# Function declarations

# %%
def analyse_sentiment(text):
    # Tokenize and predict
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    with torch.no_grad():
        logits = finbert(**inputs).logits

    # Softmax to get probabilities
    probabilities = torch.softmax(logits, dim=1).squeeze()

    # Assuming the order of probabilities is [negative, neutral, positive]
    sentiment_labels = ['neutral', 'positive', 'negative']

    # Getting the index of the max probability
    label_idx = torch.argmax(probabilities).item()
    label = sentiment_labels[label_idx]

    # Continuous sentiment score calculation
    sentiment_score = probabilities[0] * 0 + probabilities[1] * 1 + probabilities[2] * -1

    return label, sentiment_score.item()

# %%
# Example usage
bullish_text_6 = """The S&P 500 index, a benchmark for U.S. stock market performance, soared to new heights today, reflecting a surge of optimism among investors about the robustness of the American economy.
In a remarkable display of market confidence, the S&P 500 climbed sharply in early trading and sustained its gains throughout the day. Analysts attribute this bullish trend to a confluence of favorable economic indicators and corporate earnings reports that have exceeded expectations.
Recent data showing a resilient job market, coupled with strong consumer spending, have eased concerns about a potential economic downturn. Moreover, inflation rates have shown signs of stabilizing, bolstering investor confidence in the Federal Reserve's monetary policy measures.
Leading the charge were tech giants, which saw significant gains as investors responded positively to their latest earnings reports and future growth prospects. Additionally, energy and healthcare sectors contributed to the index's upward trajectory, reflecting broader market strength.
Economists are viewing this rally as a sign of enduring economic health, despite challenges such as geopolitical tensions and supply chain disruptions. The market's performance is seen as a barometer of investor sentiment, indicating a belief in the resilience and potential of the U.S. economy.
Investors are also buoyed by the global economic outlook, which appears to be stabilizing after a period of uncertainty. This has led to increased capital flows into U.S. equities, further driving the market's growth.
As the S&P 500 sets new records, market participants remain cautiously optimistic, with a keen eye on upcoming economic reports and global events. However, today's market performance is undeniably a strong indicator of the underlying strength of the American economy and the confidence of investors in its continued growth."""

bullish_text_1 = """
Market analysts are expressing heightened optimism as the latest economic indicators suggest a robust uptrend in consumer spending,
which is often a precursor to sustained growth in the stock market. Leading financial experts have revised their forecasts,
predicting a bullish wave that could see significant gains across multiple sectors. The technology sector, in particular,
is poised to benefit from this surge, with pioneering firms at the forefront of innovation expected to outperform.
Investor sentiment is buoyed by the convergence of favorable market conditions and groundbreaking advancements in digital commerce.
"""

bullish_text_2 = """
Investors are riding a wave of enthusiasm as blue-chip companies report earnings that shatter expectations,
signaling a bullish trend that is likely to continue for the foreseeable future. The energy sector is witnessing a remarkable recovery,
spurred by strategic shifts toward sustainable practices and green technology, which are garnering widespread support from institutional investors.
Market sentiment has been galvanized by these positive developments, driving a rally that shows no signs of abating.
"""

bullish_text_3 = """
In an unprecedented turn of events, the stock market has embarked on an upward trajectory that has seasoned traders and new investors alike
looking forward to a prosperous financial quarter. With the Fed's recent policy adjustments laying a solid foundation for economic stability,
the market's buoyancy is further amplified by the influx of foreign capital into U.S. equities. Analysts are bullish on the market's prospects,
citing the alignment of fiscal incentives and a surge in entrepreneurial ventures as key drivers of this financial renaissance.
"""

bullish_text_4 = """
The financial markets are abuzz with excitement as mid-cap stocks emerge as the new darlings of Wall Street,
drawing in a flurry of bullish activity. These companies, characterized by their innovative business models and agile adaptability,
are the engines of growth, according to leading market strategists. As they outpace their larger counterparts in percentage gains,
a number of these stocks are on the cusp of being reclassified as large-cap, a testament to their success and the positive market sentiment surrounding them.
"""

bullish_text_5 = """
Today marks a momentous day in the financial markets as merger and acquisition activities reach a five-year high,
heralding a bullish outlook that is permeating across industries. This uptick in M&A is a strong confidence signal,
indicating that corporations are not only flush with cash but are also willing to invest in growth opportunities.
The resulting synergies are expected to catalyze further stock price appreciation, much to the delight of shareholders who are eagerly anticipating the next earnings season.
"""


bearish_text_6 = """In a dramatic turn of events, the S&P 500, a widely regarded benchmark for U.S. stock market health, experienced a steep decline today, signaling deepening concerns over the state of the American economy.
Market analysts attribute this sudden drop to a combination of worsening economic indicators and disappointing corporate earnings reports, which have significantly dampened investor sentiment. Key factors contributing to this downturn include escalating inflation rates, a sluggish job market, and diminishing consumer confidence.
The tech sector, often seen as a barometer of market health, led the decline with significant losses, as investors reacted negatively to lower-than-expected earnings and cautious future projections. Similarly, the energy and healthcare sectors witnessed substantial sell-offs, reflecting widespread market pessimism.
Economists are raising alarms about the potential for a prolonged economic slowdown, pointing to persistent supply chain issues, geopolitical tensions, and policy uncertainties. The Federal Reserve's recent monetary policy decisions, aimed at curbing inflation, are also under scrutiny for potentially exacerbating the economic downturn.
Investors' fears are further fueled by a gloomy global economic outlook, marked by rising international trade conflicts and political instability in key regions. This has resulted in a flight to safer assets, leading to a significant outflow of capital from the U.S. equity markets.
Today's sharp decline in the S&P 500 is seen as a clear indicator of the growing anxiety over the future of the American economy. Market participants are bracing for potential further declines, with a cautious eye on upcoming economic data and global events.
As the market closes on this tumultuous day, the mood among investors is one of uncertainty and apprehension, reflecting the challenges facing the U.S. economy and the global financial system."""

bearish_text_1 = """
The latest quarter has sent a shiver down Wall Street as a number of bellwether companies have reported underwhelming earnings.
Economic experts warn of a looming bear market, as key indicators point to a slowdown in manufacturing and consumer confidence wanes.
Investors are advised to brace for volatility, with particular caution directed at the once-booming tech sector,
which is now facing regulatory headwinds and a significant downturn in consumer demand.
"""

bearish_text_2 = """
As the fiscal year draws to a close, analysts are sounding the alarm on the potential for a steep market correction.
The once-stalwart real estate sector is showing cracks as interest rates rise, leading to a bearish outlook among investors.
With market liquidity tightening and debt levels reaching unsustainable highs, the possibility of a cascading effect on stock prices is becoming a palpable fear.
"""

bearish_text_3 = """
The stock market's bull run appears to be on its last legs, according to several hedge fund managers who have started to take short positions in anticipation of a downturn.
With consumer debt reaching an all-time high and job growth stalling, the economic outlook is decidedly bearish.
Market sentiment has taken a hit as trade tensions continue to escalate, leaving investors scrambling to adjust their portfolios.
"""

bearish_text_4 = """
In a startling development, several high-profile IPOs have failed to meet their target valuations, casting a long shadow over the venture capital landscape.
The ripple effects are being felt across the market, as investors grow increasingly bearish on the prospects of tech startups.
With venture funding drying up, the specter of widespread layoffs looms large, further dampening market enthusiasm.
"""

bearish_text_5 = """
Market optimism has taken a nosedive as geopolitical uncertainties and weakening currency values contribute to a bearish outlook for international markets.
Investors are pulling back from emerging markets, resulting in a flight to safety that has bolstered the dollar but left riskier assets exposed to sharp declines.
As the global economic picture grows murkier, the possibility of a protracted bear market is becoming a central narrative among financial commentators.
"""


neutral_bearish_text = """

In today's market overview, investors have approached the trading day with measured expectations. The majority of sectors held steady, reflecting a market in equilibrium, though consumer goods saw a slight rise, attributed to more than forecasted retail sales reports this quarter. Financial analysts maintain a good stance, acknowledging the stability of key indices while noting the potential for slower growth in retail as a point of mild concern. Amid this tempered outlook, the energy sector sustained its usual ebb and flow, with no significant price shifts to report. As the markets closed, the overarching sentiment remained neutral, with a watchful eye towards consumer trends that could suggest a cautious approach in the coming weeks."""

# %%
label, score = analyse_sentiment(bullish_text_1)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bullish_text_2)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bullish_text_3)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bullish_text_4)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bullish_text_5)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bullish_text_6)
print(f"Label: {label} Continuous Sentiment Score: {score}")
# Out:
# Label: positive Continuous Sentiment Score: 1.0
# Label: positive Continuous Sentiment Score: 0.9999973773956299
# Label: positive Continuous Sentiment Score: 1.0
# Label: positive Continuous Sentiment Score: 0.9999999403953552
# Label: positive Continuous Sentiment Score: 1.0
# Label: positive Continuous Sentiment Score: 1.0

# %%
label, score = analyse_sentiment(bearish_text_1)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bearish_text_2)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bearish_text_3)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bearish_text_4)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bearish_text_5)
print(f"Label: {label} Continuous Sentiment Score: {score}")

label, score = analyse_sentiment(bearish_text_6)
print(f"Label: {label} Continuous Sentiment Score: {score}")
# Out:
# Label: negative Continuous Sentiment Score: -0.9999980330467224
# Label: negative Continuous Sentiment Score: -0.9999986290931702
# Label: negative Continuous Sentiment Score: -0.9999982118606567
# Label: negative Continuous Sentiment Score: -0.9999989867210388
# Label: negative Continuous Sentiment Score: -0.999993085861206
# Label: negative Continuous Sentiment Score: -0.9999979138374329

# %%
label, score = analyse_sentiment(neutral_bearish_text)
print(f"Label: {label} Continuous Sentiment Score: {score}")
# Out:
# Label: positive Continuous Sentiment Score: 0.852023720741272

# %%
torch.save(finbert.state_dict(), "/content/Default_FinBERT_statedict.pth")
